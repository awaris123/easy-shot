# %%
def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
fluset = edits1("flu")
flushotset = edits1("flu shot")
fluvaccineset = edits1("flu vaccine")
influenzaset = edits1("influenza vaccine")

# %%
flu = fluset | flushotset | fluvaccineset | influenzaset

# %%
print(flu)
print(len(flu))
# Out:
# {'fludshot', 'flu shmt', 'fklu shot', 'influenza vzaccine', 'flu vaccixne', 'iqfluenza vaccine', 'slu', 'olu vaccine', 'ginfluenza vaccine', 'flu shozt', 'flu vafcine', 'influenzasvaccine', 'icnfluenza vaccine', 'flu vacczine', 'flu vaccinbe', 'influenza vaccixe', 'flu vaccinea', 'flu vaccini', 'flu ohot', 'nlu shot', 'flfu shot', 'knfluenza vaccine', 'fxu', 'elu vaccine', 'infkluenza vaccine', 'flu vaccivne', 'flulvaccine', 'influenzia vaccine', 'influenzazvaccine', 'influenza vamccine', 'fblu vaccine', 'fluoshot', 'flu vacciny', 'flu shon', 'fluu shot', 'influenza vacciwne', 'fluovaccine', 'flu tvaccine', 'flushot', 'influenza vacctine', 'flu vaceine', 'influeynza vaccine', 'pnfluenza vaccine', 'influuenza vaccine', 'influenzb vaccine', 'influenza vcaccine', 'iofluenza vaccine', 'fqlu', 'flwu shot', 'imnfluenza vaccine', 'fiu vaccine', 'influenzag vaccine', 'influenzak vaccine', 'fluo shot', 'flu sjhot', 'flur', 'flu shto', 'flu shuot', 'flu vaccdine', 'flf vaccine', 'dinfluenza vaccine', 'flu paccine', 'fl vaccine', 'flu maccine', 'falu', 'fllu vaccine', 'influenza accine', 'infxuenza vaccine', 'influenze vaccine', 'fl ushot', 'flu shst', 'flu wshot', 'flu snot', 'flu vaccline', 'flu spot', 'influenza vaccire', 'influenza varccine', 'influenza vacchine', 'flu sthot', 'influenzya vaccine', 'influeza vaccine', 'flut shot', 'flu vaccmine', 'idnfluenza vaccine', 'influentza vaccine', 'inflxenza vaccine', 'influenza mvaccine', 'uflu', 'fclu vaccine', 'ffu', 'influenza vaccin', 'flu shoft', 'flu vaccinye', 'flu scot', 'infltenza vaccine', 'flu gshot', 'infludnza vaccine', 'iffluenza vaccine', 'flq vaccine', 'flu shop', 'flu shat', 'vlu vaccine', 'influsenza vaccine', 'influednza vaccine', 'influenza waccine', 'influwenza vaccine', 'influenlza vaccine', 'enfluenza vaccine', 'influenza vlaccine', 'fsu vaccine', 'influenza jaccine', 'influenza vpccine', 'flul shot', 'influenza vacoine', 'xnfluenza vaccine', 'influenza paccine', 'xflu', 'flu sohot', 'fl uvaccine', 'ionfluenza vaccine', 'influenzea vaccine', 'influegza vaccine', 'ixnfluenza vaccine', 'flu vaccfne', 'flvu shot', 'flulshot', 'flu shoc', 'influenza vacqine', 'flu vhot', 'fle', 'fl shot', 'flu sbot', 'flu suot', 'flu svhot', 'flurvaccine', 'flu vaccine', 'flu vaccinu', 'influenza vcacine', 'influenzacvaccine', 'influenzc vaccine', 'influenza saccine', 'flu shoo', 'flu vnccine', 'flu vaccineb', 'flue vaccine', 'influenza vuaccine', 'flu vaccnne', 'flu vgccine', 'fdlu shot', 'influenza vaqcine', 'influenza vaccime', 'influenzua vaccine', 'fly vaccine', 'influbnza vaccine', 'influenzu vaccine', 'flf', 'influenza vaczcine', 'fou vaccine', 'influenza vatccine', 'flu vapcine', 'influenzatvaccine', 'flut', 'fglu vaccine', 'influenza rvaccine', 'sinfluenza vaccine', 'flpu', 'flu vaccide', 'yflu', 'flj vaccine', 'flu vaccne', 'flu vyccine', 'influenza vaccinre', 'flu vacxcine', 'tlu', 'flu vaccipe', 'influnza vaccine', 'flu vacciner', 'flul vaccine', 'influenza vaccpine', 'flnu', 'fluf vaccine', 'influvenza vaccine', 'flu vaccqine', 'tflu', 'flu vacchine', 'influecnza vaccine', 'plu shot', 'influenza pvaccine', 'flu faccine', 'icfluenza vaccine', 'influebza vaccine', 'fylu shot', 'flu vaccive', 'flug vaccine', 'flu pvaccine', 'influenza vaccioe', 'flxu shot', 'fluj vaccine', 'flu shoe', 'flud', 'kinfluenza vaccine', 'fslu vaccine', 'influenza vaccinw', 'influenza vakccine', 'fmlu', 'flu vaccnine', 'influenzoa vaccine', 'flu vacciney', 'fqu vaccine', 'fluv vaccine', 'inlfluenza vaccine', 'flu vaccike', 'flu vaccikne', 'flujvaccine', 'flu vacyine', 'flun shot', 'fclu shot', 'influenzt vaccine', 'flugvaccine', 'flu dhot', 'flu vaccione', 'flu sphot', 'mflu vaccine', 'fflu vaccine', 'influienza vaccine', 'flu vcaccine', 'wlu', 'inefluenza vaccine', 'flu ushot', 'flu sot', 'flu vaccije', 'influenza gaccine', 'wflu shot', 'flu vancine', 'fluqvaccine', 'inflfuenza vaccine', 'influenza vaccinec', 'flu tshot', 'influenzla vaccine', 'flu zshot', 'flu ssot', 'flu shyot', 'influenza vgccine', ...
# 2134
